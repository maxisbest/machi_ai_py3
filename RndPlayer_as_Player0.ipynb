# %% [markdown]
# ## RndPlayer as Player[0]

# %%
# tf.__version__ = 1.13.1; np.__version__ = 1.16.3

from game import Game
from player import Player
from player_ai import PlayerAI
from copy import deepcopy
#from rnd_player import RndPlayer
from constants import *

import numpy as np
import sys

#BUILDING ORDER
# BUILDING_ORDER_ = BUILDING_ORDER + ['DO NOT BUY']

#when in training, you need to set 📌 load=False; 📌 use_max_probability=True; 📌 g_shuffle=True
# the following setting is for battle.
kwargs = {'load':True,
          'name':'',
          'verbose':True,
          'use_max_probability':True,
          'shared_ai':True,
          'game_record_filename':'',  #这个值设为''就不会记录战斗过程了, battle_log.log
          'prob_mod':0.0,
          'g_shuffle':False
         }
print(kwargs)

game = Game(0,name='t001',options=kwargs)
players = game.players

print("player1 and player3 has the same AI.dice_ai?")
print(players[1].AI.dice_ai == players[3].AI.dice_ai) #No

players[1].load_ai(True)

#player1_3 = []
for i in range(2,4):
    players[i].AI.dice_ai = players[1].AI.dice_ai
    players[i].AI.reroll_ai = players[1].AI.reroll_ai
    players[i].AI.steal_ai = players[1].AI.steal_ai
    players[i].AI.swap_ai = players[1].AI.swap_ai
    players[i].AI.buy_ai = players[1].AI.buy_ai

print(players[1].AI.dice_ai == players[3].AI.dice_ai) #Yes
print(players[0].AI.dice_ai == players[1].AI.dice_ai) #No

#players[0].AI = PlayerAI(players[0])  #这个操作会改变
players[0].AI.initialize_ai()

print("player0 and player1 has the same AI.buy_ai?")
print(players[0].AI.buy_ai == players[1].AI.buy_ai)
print(players[0].order)

for player in players:
    player.win=0
# i = np.random.randint(1, 10000, 1)[0]
# game = Game(i, name=name, options=kwargs)

game.players=players
game.run()
# Out:
# Using TensorFlow backend.
# ...end...
# {'load': True, 'name': '', 'verbose': True, 'use_max_probability': True, 'shared_ai': True, 'game_record_filename': '', 'prob_mod': 0.0, 'g_shuffle': False}
# WARNING:tensorflow:From c:\users\maxyi\envs\tfenv\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\users\maxyi\envs\tfenv\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# player1 and player3 has the same AI.dice_ai?
# False
# WARNING:tensorflow:From c:\users\maxyi\envs\tfenv\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# loaded ai
# True
# False
# player0 and player1 has the same AI.buy_ai?
# False
# 0
# Beginning game #0
# Player 2, order 2 won in 63 turns
# [<player.Player at 0x23a3359b400>,
#  <player.Player at 0x23a3359bf28>,
#  <player.Player at 0x23a335a69b0>,
#  <player.Player at 0x23a3358ed30>]

# %%
print(f"{players[0].win}, {players[1].win}, {players[2].win} {players[3].win}")
# Out:
# 0, 0, 1 0

# %%
kwargs = {'load': False,
          'name': '',
          'verbose': False,
          'use_max_probability': True,
          'shared_ai': False,  # 这里要设为False, 否则上面的4个AI又会用同样的神经网络了。不过player在初始化的时候, 这个属性默认是False的。
          'game_record_filename': '',  # 这个值设为''就不会记录战斗过程了, battle_log.log
          'prob_mod': 0.0,
          'g_shuffle': False
          }
print(kwargs)

who_won = []
for i in range(100):
    game = Game(i, name=str(i), options=kwargs)
    # reset_game
    game.players = players
    for j in range(4):
        players[j].game = game
        players[j].buildings = deepcopy(starting_buildings)
        players[j].coins = 3
        players[j].order = j
        players[j].win = 0

    game.run(silent=True)
    print(f"game{i} finished with {game.turn} turns.", end=' ')

    for k in range(4):
        if players[k].win:
            who_won.append(players[k].order)
            print(f'player{k} won.')

    game.flush_player_history()
# Out:
# {'load': False, 'name': '', 'verbose': False, 'use_max_probability': True, 'shared_ai': False, 'game_record_filename': '', 'prob_mod': 0.0, 'g_shuffle': False}
# game0 finished with 66 turns. player1 won.
# game1 finished with 62 turns. player1 won.
# game2 finished with 59 turns. player2 won.
# game3 finished with 74 turns. player1 won.
# game4 finished with 67 turns. player2 won.
# game5 finished with 66 turns. player1 won.
# game6 finished with 76 turns. player3 won.
# game7 finished with 71 turns. player2 won.
# game8 finished with 63 turns. player2 won.
# game9 finished with 86 turns. player1 won.
# game10 finished with 66 turns. player1 won.
# game11 finished with 80 turns. player3 won.
# game12 finished with 54 turns. player1 won.
# game13 finished with 50 turns. player1 won.
# game14 finished with 68 turns. player3 won.
# game15 finished with 72 turns. player3 won.
# game16 finished with 74 turns. player1 won.
# game17 finished with 70 turns. player1 won.
# game18 finished with 62 turns. player1 won.
# game19 finished with 62 turns. player1 won.
# game20 finished with 54 turns. player1 won.
# game21 finished with 71 turns. player2 won.
# game22 finished with 70 turns. player1 won.
# game23 finished with 51 turns. player2 won.
# game24 finished with 55 turns. player2 won.
# game25 finished with 55 turns. player2 won.
# game26 finished with 56 turns. player3 won.
# game27 finished with 54 turns. player1 won.
# game28 finished with 58 turns. player1 won.
# game29 finished with 55 turns. player2 won.
# game30 finished with 66 turns. player1 won.
# game31 finished with 76 turns. player3 won.
# game32 finished with 55 turns. player2 won.
# game33 finished with 59 turns. player2 won.
# game34 finished with 64 turns. player3 won.
# game35 finished with 55 turns. player2 won.
# game36 finished with 55 turns. player2 won.
# game37 finished with 54 turns. player1 won.
# game38 finished with 75 turns. player2 won.
# game39 finished with 74 turns. player1 won.
# game40 finished with 54 turns. player1 won.
# game41 finished with 78 turns. player1 won.
# game42 finished with 75 turns. player2 won.
# game43 finished with 72 turns. player3 won.
# game44 finished with 58 turns. player1 won.
# game45 finished with 54 turns. player1 won.
# game46 finished with 58 turns. player1 won.
# game47 finished with 43 turns. player2 won.
# game48 finished with 54 turns. player1 won.
# game49 finished with 66 turns. player1 won.
# game50 finished with 68 turns. player3 won.
# game51 finished with 62 turns. player1 won.
# game52 finished with 72 turns. player3 won.
# game53 finished with 72 turns. player3 won.
# game54 finished with 78 turns. player1 won.
# game55 finished with 67 turns. player2 won.
# game56 finished with 66 turns. player1 won.
# game57 finished with 70 turns. player1 won.
# game58 finished with 55 turns. player2 won.
# game59 finished with 62 turns. player1 won.
# game60 finished with 63 turns. player2 won.
# game61 finished with 75 turns. player2 won.
# game62 finished with 66 turns. player1 won.
# game63 finished with 63 turns. player2 won.
# game64 finished with 48 turns. player3 won.
# game65 finished with 64 turns. player3 won.
# game66 finished with 76 turns. player3 won.
# game67 finished with 62 turns. player1 won.
# game68 finished with 74 turns. player1 won.
# game69 finished with 54 turns. player1 won.
# game70 finished with 78 turns. player1 won.
# game71 finished with 54 turns. player1 won.
# game72 finished with 56 turns. player3 won.
# game73 finished with 55 turns. player2 won.
# game74 finished with 78 turns. player1 won.
# game75 finished with 79 turns. player2 won.
# game76 finished with 71 turns. player2 won.
# game77 finished with 66 turns. player1 won.
# game78 finished with 56 turns. player3 won.
# game79 finished with 76 turns. player3 won.
# game80 finished with 74 turns. player1 won.
# game81 finished with 70 turns. player1 won.
# game82 finished with 54 turns. player1 won.
# game83 finished with 70 turns. player1 won.
# game84 finished with 64 turns. player3 won.
# game85 finished with 62 turns. player1 won.
# game86 finished with 67 turns. player2 won.
# game87 finished with 58 turns. player1 won.
# game88 finished with 83 turns. player2 won.
# game89 finished with 67 turns. player1 won.
# game90 finished with 74 turns. player1 won.
# game91 finished with 65 turns. player2 won.
# game92 finished with 63 turns. player2 won.
# game93 finished with 56 turns. player3 won.
# game94 finished with 64 turns. player3 won.
# game95 finished with 79 turns. player2 won.
# game96 finished with 75 turns. player2 won.
# game97 finished with 55 turns. player2 won.
# game98 finished with 58 turns. player1 won.
# game99 finished with 69 turns. player3 won.
# game100 finished with 67 turns. player2 won.
# game101 finished with 58 turns. player1 won.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-c5243dcdfb85> in <module>
#      22         players[j].win = 0
#      23
# ---> 24     game.run(silent=True)
#      25     print(f"game{i} finished with {game.turn} turns.", end=' ')
#      26
#
# ~\ai\machi_ai_py3\game.py in run(self, silent)
#      72                 self.record_full_game_state()
#      73
# ---> 74             current_player.take_turn()
#      75
#      76             if current_player.win:
#
# ~\ai\machi_ai_py3\player.py in take_turn(self)
#     258
#     259         #buy
# --> 260         self.decide_buy()
#     261         if self.buy_choice != 19:
#     262             self.buildings[BUILDING_ORDER[self.buy_choice]] += 1
#
# ~\ai\machi_ai_py3\player.py in decide_buy(self)
#     333     def decide_buy(self):
#     334         self.create_buy_mask()
# --> 335         probs = self.AI.eval_buy()
#     336         self.buy_choice =  choose_from_probs(probs, constraint_mask = self.buy_mask)
#     337         self.AI.record_buy()
#
# ~\ai\machi_ai_py3\player_ai.py in eval_buy(self)
#     187         extra_input = np.concatenate((extra_input, np.zeros( (1,19) ), ))
#     188         input = self.merge_input(extra_input)
# --> 189         preds = self.buy_ai.predict(input)
#     190         return preds[:,1]
#     191
#
# c:\users\maxyi\envs\tfenv\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# c:\users\maxyi\envs\tfenv\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# c:\users\maxyi\envs\tfenv\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2695
#    2696     def __call__(self, inputs):
# -> 2697         if hasattr(get_session(), '_make_callable_from_options'):
#    2698             if py_any(is_sparse(x) for x in self.inputs):
#    2699                 if py_any(is_tensor(x) for x in inputs):
#
# c:\users\maxyi\envs\tfenv\lib\site-packages\keras\backend\tensorflow_backend.py in get_session()
#     197                 # not already marked as initialized.
#     198                 is_initialized = session.run(
# --> 199                     [tf.is_variable_initialized(v) for v in candidate_vars])
#     200                 uninitialized_vars = []
#     201                 for flag, v in zip(is_initialized, candidate_vars):
#
# c:\users\maxyi\envs\tfenv\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\users\maxyi\envs\tfenv\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# c:\users\maxyi\envs\tfenv\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# c:\users\maxyi\envs\tfenv\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# c:\users\maxyi\envs\tfenv\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1315     def _run_fn(feed_dict, fetch_list, target_list, options, run_metadata):
#    1316       # Ensure any changes to the graph are reflected in the runtime.
# -> 1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
#    1319           options, feed_dict, fetch_list, target_list, run_metadata)
#
# c:\users\maxyi\envs\tfenv\lib\site-packages\tensorflow\python\client\session.py in _extend_graph(self)
#    1350   def _extend_graph(self):
#    1351     with self._graph._session_run_lock():  # pylint: disable=protected-access
# -> 1352       tf_session.ExtendSession(self._session)
#    1353
#    1354   # The threshold to run garbage collection to delete dead tensors.
#
# KeyboardInterrupt:

# %%
len(who_won) #102
who_won_arr = np.array(who_won)

won_by_0 = np.sum((who_won_arr == 0)) # 0
won_by_1 = np.sum(who_won_arr == 1)  # 49
won_by_2 = np.sum(who_won_arr == 2)  # 32
won_by_3 = np.sum((who_won_arr == 3))  # 21

print(len(who_won_arr))  #102
print(won_by_0, won_by_1, won_by_2, won_by_3)
